# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# %%
img = plt.imread('ContactLens.tif')
plt.imshow(img, cmap='gray')
plt.show()

# %%
img_array = np.array(img)
img_array
# Out:
# array([[50, 51, 51, ..., 53, 52, 52],
#        [51, 51, 52, ..., 51, 52, 52],
#        [51, 52, 52, ..., 53, 52, 52],
#        ...,
#        [58, 59, 60, ..., 66, 64, 63],
#        [57, 58, 59, ..., 65, 64, 64],
#        [56, 57, 59, ..., 65, 63, 62]], dtype=uint8)

# %%
img_array = np.array(img)
for i in range(932):
    for j in range(937):
        if(img_array[i][j] > 120):
            img_array[i][j] = 255
        elif(img_array[i][j] < 100):
            img_array[i][j] = 255
        else:
            img_array[i][j] = 0
img_array        
plt.imshow(img_array, cmap='gray')
plt.show()
# img_array[400]

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
image = cv2.imread("ContactLens.tif")#读入图像
image = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)#将图像转化为灰度图像
#cv2.imshow("Image",image)#显示图像
# cv2.waitKey()
canny = cv2.Canny(image,30,150)
# cv2.imshow("Canny",canny)
# cv2.waitKey()
plt.imshow(canny, cmap='gray')
img_array = np.array(canny)
# img_array[400]
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-cfea2ed9c1df> in <module>()
#       1 import numpy as np
# ----> 2 import cv2
#       3 import matplotlib.pyplot as plt
#       4 image = cv2.imread("ContactLens.tif")#读入图像
#       5 image = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)#将图像转化为灰度图像
#
# ModuleNotFoundError: No module named 'cv2'

# %%
kernel = np.ones((2,2),np.uint8)  
dilation = cv2.dilate(canny,kernel,iterations = 1)
# plt.imshow(dilation, cmap='gray')
# img_array = np.array(dilation)
img_array[400]
cv2.imshow("dilation",dilation)

# %%
kernel = np.ones((3,3),np.uint8)  
closing = cv2.morphologyEx(canny, cv2.MORPH_CLOSE, kernel)
plt.imshow(closing, cmap='gray')
img_array = np.array(closing)
# img_array[400]
cv2.imshow("closing",closing)
cv2.waitKey()
cv2.destroyAllWindows()
